# %%
import pandas as pd
import json

# %%
with open('data/tour-de-france_2023_stage_1.json', 'r') as file:
    sj = json.load(file)

# %%
sj.keys()
# Out:
# dict_keys(['arrival', 'avg_speed_winner', 'avg_temperature', 'climbs', 'date', 'departure', 'distance', 'gc', 'is_one_day_race', 'kom', 'pcs_points_scale', 'points', 'profile_icon', 'profile_score', 'race_category', 'race_startlist_quality_score', 'results', 'stage_type', 'start_time', 'teams', 'uci_points_scale', 'vertical_meters', 'winning_attack_length', 'won_how', 'youth'])

# %%
sj['profile_icon']
# Out:
# 'p3'

# %%
pd.DataFrame(sj['points'])
# Out:
#            rider_name                       rider_url  rider_number  \
# 0          YATES Adam                rider/adam-yates            19
# 1         YATES Simon               rider/simon-yates           161
# 2       POGAČAR Tadej             rider/tadej-pogacar            11
# 3    EENKHOORN Pascal          rider/pascal-eenkhoorn           184
# 4       PINOT Thibaut             rider/thibaut-pinot            37
# 5       WOODS Michael             rider/michael-woods           151
# 6     GUGLIELMI Simon           rider/simon-guglielmi           175
# 7        LAFAY Victor              rider/victor-lafay           125
# 8     FERRON Valentin           rider/valentin-ferron           215
# 9         HINDLEY Jai               rider/jai-hindley            71
# 10   CALMEJANE Lilian          rider/lilian-calmejane           112
# 11  SKJELMOSE Mattias  rider/mattias-skjelmose-jensen            83
# 12     GREGAARD Jonas            rider/jonas-gregaard           208
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
URL = "https://www.procyclingstats.com/race/tour-de-france/2023/stage-1"
page = requests.get(URL)

# %%
with open('data/html/tour-de-france_2023_stage-1.html', 'wb') as file:
    file.write(page.content)

# %%
with open('data/html/tour-de-france_2023_stage-1.html', 'r') as file:
    page_content = file.read()

# %%
soup = BeautifulSoup(page_content, "html.parser")

# %%
tables = soup.find_all('table')

# %%
len(tables)
# Out:
# 15

# %%
pd.read_html(str(tables[0]))
# Out:
# C:\Users\maric\AppData\Local\Temp\ipykernel_12096\26857470.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(str(tables[0]))
# [     Rnk     GC Timelag  BIB  H2H Specialty  \
#  0      1    1.0   +0:00   19  NaN   Climber
#  1      2    2.0   +0:08  161  NaN   Climber
#  2      3    3.0   +0:18   11  NaN   Climber
#  3      4    4.0   +0:22   37  NaN   Climber
#  4      5    5.0   +0:22  151  NaN   Climber
#  ..   ...    ...     ...  ...  ...       ...
#  171  172  172.0  +21:32  192  NaN    Sprint
#  172  173  173.0  +21:32   64  NaN    Sprint
#  173  174  174.0  +21:32  194  NaN   Classic
#  174  175  175.0  +21:32  186  NaN    Sprint
#  175  DNF    NaN     NaN  131  NaN   Climber
#
#                                        Rider  Age                   Team  \
#  0              YATES Adam UAE Team Emirates   30      UAE Team Emirates
# ...
